# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# Create your data api of kaggle

# %% [markdown]
# ![kaggle_api.png](data:image/png;base64,...)

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content}

# %%
# !kaggle datasets list

# %%
# !kaggle competitions download -c shopee-product-matching -p /content/drive/MyDrive/shopee/

# %%
# !unzip /content/drive/MyDrive/shopee/input/shopee-product-matching/shopee-product-matching.zip -d /content/drive/MyDrive/shopee/input/
